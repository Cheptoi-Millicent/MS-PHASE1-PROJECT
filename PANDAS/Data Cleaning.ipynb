# %%
# Load the required libraries
import pandas as pd

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel("Sample Superstore.xlsx")

# %% [markdown]
# df.head()

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df.tail()
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 9421  Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422  Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423  Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424   Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425   Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
# ...

# %%
shape = df.shape
print(f"My dataset has {shape[0]} rows and {shape[1]} columns")
# Out:
# My dataset has 9426 rows and 24 columns

# %%
df.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
#
#        Product Base Margin   Postal Code        Profit  Quantity ordered new  \
# count          9354.000000   9426.000000   9426.000000           9426.000000
# mean              0.512189  52446.327286    139.236410             13.798430
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
df.isnull().value_counts()
# Out:
# Row ID  Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  Customer Name  Ship Mode  Customer Segment  Product Category  Product Sub-Category  Product Container  Product Name  Product Base Margin  Region  State or Province  City   Postal Code  Order Date  Ship Date  Profit  Quantity ordered new  Sales  Order ID
# False   False           False     False       False          False        False          False      False             False             False                 False              False         False                False   False              False  False        False       False      False   False                 False  False       9354
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %% [markdown]
# # Check for duplicates

# %%
df["Row ID"].duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset=['City','Region']).sum()
# Out:
# 7886

# %%
df.drop_duplicates()
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df.duplicated(keep=False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9421    False
# 9422    False
# 9423    False
# 9424    False
# 9425    False
# Length: 9426, dtype: bool

# %%
df.duplicated(keep='last')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9421    False
# 9422    False
# 9423    False
# 9424    False
# 9425    False
# Length: 9426, dtype: bool

# %%
book = pd.read_excel("Book1.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [20], line 1
# ----> 1 book = pd.read_excel("Book1.xlsx")
#
# File c:\Users\Administrator\anaconda3\envs\learn-env\lib\site-packages\pandas\util\_decorators.py:296, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     291     msg = (
#     292         f"Starting with Pandas version {version} all arguments of "
#     293         f"{func.__name__}{arguments} will be keyword-only"
#     294     )
#     295     warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296 return func(*args, **kwargs)
#
# ...

# %%
book.duplicated().sum()
# Out:
# 1

# %%
book.drop_duplicates()
# Out:
#     ID    Name   Age
# 0    1  Daniel  24.0
# 1    2     NaN  31.0
# 2    3   Faith   NaN
# 3    1    John  14.0
# 4    5     NaN  15.0
# 5    2    Abdi   NaN
# 6    6    Abel  24.0
# 7    4    Rose  15.0
# 8    5     NaN   NaN
# 10   1   James   NaN
# 11   5   David  15.0

# %%
book.duplicated(keep=False)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# dtype: bool

# %%
book1 = book[book.duplicated(keep="last")]

# %%
book1
# Out:
#    ID    Name   Age
# 0   1  Daniel  24.0

# %% [markdown]
# # Null Values:

# %%
book
# Out:
#     ID    Name   Age
# 0    1  Daniel  24.0
# 1    2     NaN  31.0
# 2    3   Faith   NaN
# 3    1    John  14.0
# 4    5     NaN  15.0
# 5    2    Abdi   NaN
# 6    6    Abel  24.0
# 7    4    Rose  15.0
# 8    5     NaN   NaN
# 9    1  Daniel  24.0
# 10   1   James   NaN
# 11   5   David  15.0

# %%
book['Name'].ffill()
# Out:
# 0     Daniel
# 1     Daniel
# 2      Faith
# 3       John
# 4       John
# 5       Abdi
# 6       Abel
# 7       Rose
# 8       Rose
# 9     Daniel
# 10     James
# 11     David
# Name: Name, dtype: object

# %%
book.isna().sum()
# Out:
# ID      0
# Name    3
# Age     4
# dtype: int64

# %%
dropped_na = book.dropna()
dropped_na
# Out:
#     ID    Name   Age
# 0    1  Daniel  24.0
# 3    1    John  14.0
# 6    6    Abel  24.0
# 7    4    Rose  15.0
# 9    1  Daniel  24.0
# 11   5   David  15.0

# %%
book.Name.isna().sum()
# Out:
# 3

# %%
mode_name = book['Name'].mode()[0]
mode_name

# book['Name'] = book['Name'].fillna(mode_name)
# Out:
# 'Daniel'

# %%
# book

# %%
# book['Age'].mean()

# %%
mean = book['Age'].mean()
#book['Age'] = book['Age'].fillna(mean)
#book

# %%
book
# Out:
#     ID    Name   Age
# 0    1  Daniel  24.0
# 1    2     NaN  31.0
# 2    3   Faith   NaN
# 3    1    John  14.0
# 4    5     NaN  15.0
# 5    2    Abdi   NaN
# 6    6    Abel  24.0
# 7    4    Rose  15.0
# 8    5     NaN   NaN
# 9    1  Daniel  24.0
# 10   1   James   NaN
# 11   5   David  15.0

# %%
book['Name'] = book['Name'].ffill()

# %%
book['Age'] = book['Age'].bfill()

# %%
book
# Out:
#     ID    Name   Age
# 0    1  Daniel  24.0
# 1    2  Daniel  31.0
# 2    3   Faith  14.0
# 3    1    John  14.0
# 4    5    John  15.0
# 5    2    Abdi  24.0
# 6    6    Abel  24.0
# 7    4    Rose  15.0
# 8    5    Rose  24.0
# 9    1  Daniel  24.0
# 10   1   James  15.0
# 11   5   David  15.0

# %%
# add column retire = age + 30
book['Retire'] = book['Age'] + 30
book
# Out:
#     ID    Name   Age  Retire
# 0    1  Daniel  24.0    54.0
# 1    2  Daniel  31.0    61.0
# 2    3   Faith  14.0    44.0
# 3    1    John  14.0    44.0
# 4    5    John  15.0    45.0
# 5    2    Abdi  24.0    54.0
# 6    6    Abel  24.0    54.0
# 7    4    Rose  15.0    45.0
# 8    5    Rose  24.0    54.0
# 9    1  Daniel  24.0    54.0
# 10   1   James  15.0    45.0
# 11   5   David  15.0    45.0

# %%
book = book.rename(columns={'Retire':'Retirement', 'Age':'Ageset'})

# %%
book.iloc[1,1] = "Daniel Ekale"

# %%
book
# Out:
#     ID          Name  Ageset  Retirement
# 0    1        Daniel    24.0        54.0
# 1    2  Daniel Ekale    31.0        61.0
# 2    3         Faith    14.0        44.0
# 3    1          John    14.0        44.0
# 4    5          John    15.0        45.0
# 5    2          Abdi    24.0        54.0
# 6    6          Abel    24.0        54.0
# 7    4          Rose    15.0        45.0
# 8    5          Rose    24.0        54.0
# 9    1        Daniel    24.0        54.0
# 10   1         James    15.0        45.0
# 11   5         David    15.0        45.0

# %%
book.drop_duplicates(inplace=True)

# %%
book
# Out:
#     ID          Name  Ageset  Retirement
# 0    1        Daniel    24.0        54.0
# 1    2  Daniel Ekale    31.0        61.0
# 2    3         Faith    14.0        44.0
# 3    1          John    14.0        44.0
# 4    5          John    15.0        45.0
# 5    2          Abdi    24.0        54.0
# 6    6          Abel    24.0        54.0
# 7    4          Rose    15.0        45.0
# 8    5          Rose    24.0        54.0
# 10   1         James    15.0        45.0
# 11   5         David    15.0        45.0
